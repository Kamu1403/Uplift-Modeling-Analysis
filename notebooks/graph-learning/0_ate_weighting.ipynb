# %%
from google.colab import data_table, drive
import os

data_table.enable_dataframe_formatter()
drive.mount('/content/drive/')
data_path = "/content/drive/MyDrive/Colab Notebooks/DSC 245 - Intro to Causal Inference"

# !pip install econml
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# Collecting econml
#   Downloading econml-0.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 30.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from econml) (1.25.2)
# Requirement already satisfied: scipy>1.4.0 in /usr/local/lib/python3.10/dist-packages (from econml) (1.11.4)
# Requirement already satisfied: scikit-learn<1.5,>=1.0 in /usr/local/lib/python3.10/dist-packages (from econml) (1.2.2)
# Collecting sparse (from econml)
#   Downloading sparse-0.15.4-py2.py3-none-any.whl (237 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 237.3/237.3 kB 31.3 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from econml) (1.4.2)
# Requirement already satisfied: statsmodels>=0.10 in /usr/local/lib/python3.10/dist-packages (from econml) (0.14.2)
# Requirement already satisfied: pandas>1.0 in /usr/local/lib/python3.10/dist-packages (from econml) (2.0.3)
# Collecting shap<0.44.0,>=0.38.1 (from econml)
#   Downloading shap-0.43.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (532 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 532.9/532.9 kB 46.9 MB/s eta 0:00:00
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (from econml) (4.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>1.0->econml) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>1.0->econml) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>1.0->econml) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<1.5,>=1.0->econml) (3.5.0)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.10/dist-packages (from shap<0.44.0,>=0.38.1->econml) (4.66.4)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.10/dist-packages (from shap<0.44.0,>=0.38.1->econml) (24.0)
# Collecting slicer==0.0.7 (from shap<0.44.0,>=0.38.1->econml)
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap<0.44.0,>=0.38.1->econml) (0.58.1)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap<0.44.0,>=0.38.1->econml) (2.2.1)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.10->econml) (0.5.6)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap<0.44.0,>=0.38.1->econml) (0.41.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.6->statsmodels>=0.10->econml) (1.16.0)
# Installing collected packages: slicer, sparse, shap, econml
# Successfully installed econml-0.15.0 shap-0.43.0 slicer-0.0.7 sparse-0.15.4

# %% [markdown]
# ## This notebook estimates Causal Relations between each feature and the target
# Average Treatment Effect (ATE) of each feature is estimated, which later used as causal weightings for GNN node embeddings

# %%
import warnings
warnings.filterwarnings("ignore")
import math
from datetime import datetime
import numpy as np
import pandas as pd
from pandas import MultiIndex
from sklearn.model_selection import StratifiedKFold
import lightgbm as lgb
# from catboost import CatBoostClassifier, Pool
import xgboost as xgb
from scipy import stats
from gensim.models import Word2Vec
import random
random.seed(2022)
np.random.seed(2022)

# %%
multi_data=pd.read_csv(os.path.join(data_path,"criteo-uplift-v2.1.csv"))
multi_data
# Out:
# Warning: total number of rows (13979592) exceeds max_rows (20000). Falling back to pandas display.
#                  f0         f1        f2        f3         f4        f5  \
# 0         12.616365  10.059654  8.976429  4.679882  10.280525  4.115453
# 1         12.616365  10.059654  9.002689  4.679882  10.280525  4.115453
# 2         12.616365  10.059654  8.964775  4.679882  10.280525  4.115453
# 3         12.616365  10.059654  9.002801  4.679882  10.280525  4.115453
# 4         12.616365  10.059654  9.037999  4.679882  10.280525  4.115453
# ...             ...        ...       ...       ...        ...       ...
# 13979587  26.297764  10.059654  9.006250  4.679882  10.280525  4.115453
# 13979588  12.642207  10.679513  8.214383 -1.700105  10.280525  3.013064
# 13979589  12.976557  10.059654  8.381868  0.842442  11.029584  4.115453
# 13979590  24.805064  10.059654  8.214383  4.679882  10.280525  4.115453
# 13979591  12.616365  10.059654  8.214383  4.679882  10.280525  3.013064
#
#                  f6        f7        f8         f9       f10       f11  \
# 0          0.294443  4.833815  3.955396  13.190056  5.300375 -0.168679
# 1          0.294443  4.833815  3.955396  13.190056  5.300375 -0.168679
# 2          0.294443  4.833815  3.955396  13.190056  5.300375 -0.168679
# 3          0.294443  4.833815  3.955396  13.190056  5.300375 -0.168679
# 4          0.294443  4.833815  3.955396  13.190056  5.300375 -0.168679
# ...             ...        ...       ...       ...        ...       ...
# 13979587  26.297764  10.059654  9.006250  4.679882  10.280525  4.115453
# 13979588  12.642207  10.679513  8.214383 -1.700105  10.280525  3.013064
# 13979589  12.976557  10.059654  8.381868  0.842442  11.029584  4.115453
# 13979590  24.805064  10.059654  8.214383  4.679882  10.280525  4.115453
# 13979591  12.616365  10.059654  8.214383  4.679882  10.280525  3.013064
#
#                  f6        f7        f8         f9       f10       f11  visit  \
# 0          0.294443  4.833815  3.955396  13.190056  5.300375 -0.168679      0
# 1          0.294443  4.833815  3.955396  13.190056  5.300375 -0.168679      0
# 2          0.294443  4.833815  3.955396  13.190056  5.300375 -0.168679      0
# 3          0.294443  4.833815  3.955396  13.190056  5.300375 -0.168679      0
# 4          0.294443  4.833815  3.955396  13.190056  5.300375 -0.168679      0
# ...             ...       ...       ...        ...       ...       ...    ...
# 13979587  -3.282109  4.833815  3.839578  13.190056  5.300375 -0.168679      0
# 13979588 -13.955150  6.269026  3.971858  13.190056  5.300375 -0.168679      0
# 13979589  -8.281971  4.833815  3.779212  23.570168  6.169187 -0.168679      1
# 13979590  -1.288207  4.833815  3.971858  13.190056  5.300375 -0.168679      0
# 13979591   0.294443  9.332563  3.971858  13.190056  5.300375 -0.168679      0
#
#           treatment
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# ...             ...
# 13979587          1
# 13979588          1
# 13979589          1
# 13979590          1
# 13979591          1
#
# [13979592 rows x 14 columns]

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

numeric_disc=[]
numeric_cont=[]

for i in data.columns :
    if len(data[i].value_counts())<=3:
            numeric_disc.append(i)
            data[i]=data[i].fillna(data[i].mode()[0])
            print("discrete",i)
            continue
    if i not in (numeric_cont+numeric_disc+["conversion"]):
        numeric_cont.append(i)
        scaler = MinMaxScaler()
        scaler=scaler.fit(np.array(data[i]).reshape(-1, 1))
        data[i]= data[i].fillna(data[i].mean())
        data[i] = scaler.transform(np.array(data[i]).reshape(-1, 1))
        print('continueous',i)
# Out:
# continueous f0
# continueous f1
# continueous f2
# continueous f3
# continueous f4
# continueous f5
# continueous f6
# continueous f7
# continueous f8
# continueous f9
# continueous f10
# continueous f11
# discrete visit
# discrete treatment

# %%
len(numeric_disc),len(numeric_cont),len(set(numeric_disc+numeric_cont))
# Out:
# (2, 12, 14)

# %% [markdown]
# ## 0 Multicollinearity

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(15,13))
cor = data.corr()

sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.title("Feature Heat Map")
plt.show()

# %%
# variance inflation factor(VIF)
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
#data = add_constant(data)
multicor=pd.DataFrame([variance_inflation_factor(data.values, i) for i in range(data.shape[1])], columns=["VIF"])
multicor["Tolerance"]=1/multicor["VIF"]
multicor["Feature"]=data.columns
multicor=multicor.sort_values(["VIF"], ascending=False )
multicor["VIF"]
# Out:
# 5     2642.777049
# 11    2507.481478
# 3      198.723595
# 8      126.867532
# 6       81.605252
# 13       6.666791
# 0        6.091387
# 9        4.277809
# 2        3.652679
# 4        2.621449
# 7        2.478556
# 10       2.142457
# 1        1.703003
# 12       1.455968
# Name: VIF, dtype: float64

# %% [markdown]
# ## 1 Average Treatment Effect (ATE) Estimation

# %%
multi_data["conversion"]
# Out:
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#            ..
# 13979587    0
# 13979588    0
# 13979589    0
# 13979590    0
# 13979591    0
# Name: conversion, Length: 13979592, dtype: int64

# %%
from imblearn.under_sampling import RandomUnderSampler
sampler = RandomUnderSampler(random_state=(2022),sampling_strategy={0:40000,1:40000})
X_sampled,y_sampled=sampler.fit_resample(data, multi_data["conversion"])

# %%
from sklearn.ensemble import GradientBoostingRegressor,GradientBoostingClassifier
from econml.dml import LinearDML, CausalForestDML

feats_ate={}
for i in X_sampled.columns:
        T=X_sampled[i]
        X=X_sampled.drop(columns=[i,])

        # Train EconML model
        if i in numeric_disc:
            est = CausalForestDML(model_y=GradientBoostingRegressor(),
                                  model_t=GradientBoostingClassifier(),
                                  cv=10,
                                  criterion='mse',
                                  n_estimators=400,
                                  min_var_fraction_leaf=0.1,
                                  min_var_leaf_on_val=True,
                                  verbose=0,
                                  n_jobs=-1,
                                  random_state=2022,
                                  discrete_treatment=True)
        else:
            est = CausalForestDML(model_y=GradientBoostingRegressor(),
                                  model_t=GradientBoostingRegressor(),
                                  cv=10,
                                  criterion='mse',
                                  n_estimators=400,
                                  min_var_fraction_leaf=0.1,
                                  min_var_leaf_on_val=True,
                                  verbose=0,
                                  n_jobs=-1,
                                  random_state=2022,
                                  discrete_treatment=False)
        est.fit(Y=y_sampled, T=T,X=X,cache_values=True) # T is matrix with size (n_samples, n_treatments)
        # Get average treatment effect to Y
        ate=est.ate(X)
        print(ate)
        print("treatments",i,"has ate of",ate,"\n")

        feats_ate[i]=ate
# Out:
# -0.013904813225682195
# treatments f0 has ate of -0.013904813225682195
#
# 0.05010206012580297
# treatments f1 has ate of 0.05010206012580297
#
# 0.0013253609753123053
# treatments f2 has ate of 0.0013253609753123053
#
# -0.009523180078206522
# treatments f3 has ate of -0.009523180078206522
#
# 0.19316792690345588
# treatments f4 has ate of 0.19316792690345588
#
# 0.001443110546813714
# treatments f5 has ate of 0.001443110546813714
#
# -0.0004962811426505234
# treatments f6 has ate of -0.0004962811426505234
#
# -0.009225854647015098
# treatments f7 has ate of -0.009225854647015098
#
# 0.10320335896145819
# treatments f8 has ate of 0.10320335896145819
#
# 0.07400411598810512
# treatments f9 has ate of 0.07400411598810512
#
# -0.016690268291158224
# treatments f10 has ate of -0.016690268291158224
#
# 0.13502199313398144
# treatments f11 has ate of 0.13502199313398144
#
# 0.9310661741225724
# treatments visit has ate of 0.9310661741225724
#
# 0.007425398326442918
# treatments treatment has ate of 0.007425398326442918

# %%
feats_ate
# Out:
# {'f0': -0.013904813225682195,
#  'f1': 0.05010206012580297,
#  'f2': 0.0013253609753123053,
#  'f3': -0.009523180078206522,
#  'f4': 0.19316792690345588,
#  'f5': 0.001443110546813714,
#  'f6': -0.0004962811426505234,
#  'f7': -0.009225854647015098,
#  'f8': 0.10320335896145819,
#  'f9': 0.07400411598810512,
#  'f10': -0.016690268291158224,
#  'f11': 0.13502199313398144,
#  'visit': 0.9310661741225724,
#  'treatment': 0.007425398326442918}

# %%
ate_df=pd.DataFrame.from_dict(feats_ate,orient='index',columns=["ATE"]).reset_index().rename({"index":"Feature"},axis=1)
ate_df=ate_df[(ate_df["Feature"]!="score") & (ate_df["Feature"]!="flag")].sort_values(["ATE"], ascending=False).reset_index(drop=True)
ate_df.to_excel(os.path.join(data_path,"feats_ate_x13.xlsx"))
